# %%
#Import dependants
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from pathlib import Path

# %%
CSV1Kpath = Path("Kaggle1DS.csv")
CSV2Kpath = Path("Kaggle2DS.csv")
CSV3Xpath = Path("SHD.csv")
CSV1KR = pd.read_csv(CSV1Kpath)
CSV2KR = pd.read_csv(CSV2Kpath)
CSV3XR = pd.read_csv(CSV3Xpath)

Firstm = pd.merge(CSV1KR, CSV2KR, on="school")
Data = pd.merge(Firstm, CSV3XR, on= "school")

# %%
Data
# Out:
#          LONCOD     LATCOD  CDCODE  year_x                          school  \
# 0    -75.584900  39.668100  1000.0    2009        William Penn High School
# 1    -75.584900  39.668100  1000.0    2009        William Penn High School
# 2    -75.584900  39.668100  1000.0    2009        William Penn High School
# 3    -83.113977  42.383593     NaN    2009             Central High School
# 4    -83.113977  42.383593     NaN    2009             Central High School
# ..          ...        ...     ...     ...                             ...
# 216  -86.031354  40.077165  1805.0    2018  Noblesville West Middle School
# 217  -86.598953  36.047367  4705.0    2018             Antioch High School
# 218 -115.135695  36.233566  3204.0    2018      Canyon Springs High School
# 219  -80.691593  35.120282  3709.0    2018              Butler High School
# 220  -76.382449  36.826811  5103.0    2018    Simonsdale Elementary School
#
#           city_x         state_x                     address  urbanrural  \
# 0     New Castle        Delaware              713 E Basin Rd  suburbtown
# 1     New Castle        Delaware              713 E Basin Rd  suburbtown
# 2     New Castle        Delaware              713 E Basin Rd  suburbtown
# 3        Detroit        Michigan              2425 Tuxedo St       urban
# 4        Detroit        Michigan              2425 Tuxedo St       urban
# ..           ...             ...                         ...         ...
# 216  Noblesville         Indiana              19900 Hague Rd  suburbtown
# 217      Antioch       Tennessee            1900 Hobson Pike       urban
# 218    Las Vegas          Nevada          350 E Alexander Rd  suburbtown
# 219     Matthews  North Carolina  1810 Matthews Mint Hill Rd  suburbtown
# 220   Portsmouth        Virginia            4841 Clifford St       urban
#
#       race  ...  State  School_Level                Location During_School  \
# 0    BLACK  ...     PA          High               Cafeteria           Yes
# 1    BLACK  ...     DE          High             Parking Lot            No
# 2    BLACK  ...     DE          High                     Gym            No
# 3      NaN  ...     IA          High                Bathroom           Yes
# 4      NaN  ...     MN          High  Inside School Building           Yes
# ..     ...  ...    ...           ...                     ...           ...
# 216  WHITE  ...     IN        Middle               Classroom           Yes
# 217  BLACK  ...     TN          High    Football Field/Track            No
# 218   HISP  ...     NV          High         Field (General)            No
# 219  WHITE  ...     NC          High                 Hallway           Yes
# 220  WHITE  ...     VA    Elementary                 Hallway            No
#
#          Time_Period  First_Shot Bullied  Domestic_Violence Gang_Related  \
# 0                NaN         NaN      No                Yes           No
# 1        Sport Event     8:50 PM      No                 No           No
# 2        Sport Event     8:30 PM      No                 No           No
# 3                NaN         NaN      No                Yes           No
# 4              Lunch    12:00 PM      No                 No           No
# ..               ...         ...     ...                ...          ...
# 216  Morning Classes     9:00 AM      No                 No           No
# 217      Sport Event     6:00 PM      No                 No           No
# 218     After School     2:40 PM      No                 No           No
# 219  Morning Classes    07:15:00     Yes                 No           No
# 220        Dismissal     4:00 PM      No                 No           No
#
#      Preplanned
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# ..          ...
# 216          No
# 217          No
# 218          No
# 219          No
# 220          No
#
# [221 rows x 80 columns]
