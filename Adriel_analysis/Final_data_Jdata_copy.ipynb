# %%
#Import dependants
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import us
from pathlib import Path
from datetime import datetime

# %% [markdown]
# (to find the full names of the states for shd_df, I had to import "us". To do this, type "pip install us" on a random cell, once installed, delete and then restart kernel to use)

# %% [markdown]
# # Data Cleaning
# ### Preparing for Analysis

# %%
CSV1Kpath = Path("Kaggle1DS.csv")
CSV2Kpath = Path("Kaggle2DS.csv")
CSV3Xpath = Path("SHD.csv")
CSV1KR = pd.read_csv(CSV1Kpath)
CSV2KR = pd.read_csv(CSV2Kpath)
CSV3XR = pd.read_csv(CSV3Xpath)

# %%
#Data frames
kaggle_1_df = pd.DataFrame(CSV1KR)
kaggle_2_df = pd.DataFrame(CSV2KR)
shd_df = pd.DataFrame(CSV3XR)

# %% [markdown]
# ### Cleaning Kaggle 1 df

# %%
#kaggle_1_df

# %%
# Organizing columns in desired order #update: took out address
clean_1_df = pd.DataFrame(kaggle_1_df[["school","type","year","date","time","city","state","urbanrural","race","killed","injured","victims","LONCOD","LATCOD"]])

# Convert "Date" column to datetime
clean_1_df["date"] = pd.to_datetime(clean_1_df["date"])

# Format the 'Date' column for display
clean_1_df["date"] = clean_1_df["date"].dt.strftime('%m/%d/%Y')

# Renaming the columns
clean_1_df.rename(columns={"urbanrural": "City Type", "LONCOD": "Longitude","LATCOD": "Latitude"}, inplace=True)

# Proper case the columns
clean_1_df.columns = [col.title() if col.islower() else col for col in clean_1_df]

# Proper case the rows
clean_1_df = clean_1_df.map(lambda x: x.title() if isinstance(x, str) else x)

# Replace NaN with "Unknown"
clean_1_df = clean_1_df.fillna("Unknown")


# Adding the newly labeled data into a new csv for cleanliness
#clean_1_path = Path("clean 1.csv")
#clean_1_df.to_csv(clean_1_path, index=False)

clean_1_df
# Out:
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/544356552.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean_1_df["date"] = pd.to_datetime(clean_1_df["date"])
#                                School               Type  Year        Date  \
# 0            William Penn High School        High School  2009  01/08/2009
# 1    Dunbar Vocational Career Academy        High School  2009  01/09/2009
# 2                 Cahokia High School        High School  2009  01/23/2009
# 3               Zebulon Middle School      Middle School  2009  02/11/2009
# 4                 Central High School        High School  2009  02/17/2009
# ..                                ...                ...   ...         ...
# 175          Denali Elementary School  Elementary School  2018  10/03/2018
# 176                Varina High School        High School  2018  10/07/2018
# 177                Butler High School        High School  2018  10/29/2018
# 178      Simonsdale Elementary School  Elementary School  2018  11/20/2018
# 179          Cawood Elementary School  Elementary School  2018  12/11/2018
#
#        Time        City           State   City Type     Race  Killed  Injured  \
# 0    8:30Pm  New Castle        Delaware  Suburbtown    Black       0        1
# 1    8:00Pm     Chicago        Illinois       Urban    Black       0        5
# 2    7:20Pm     Cahokia        Illinois  Suburbtown    Black       1        0
# 3    6:00Am     Zebulon  North Carolina  Suburbtown    Black       0        1
# 4    2:20Pm     Detroit        Michigan       Urban  Unknown       0        1
# ..      ...         ...             ...         ...      ...     ...      ...
# 175  9:30Am   Anchorage          Alaska       Urban    White       0        1
# 176  9:30Pm     Henrico        Virginia       Rural    Black       0        1
# 177  7:15Am    Matthews  North Carolina  Suburbtown    White       1        0
# 178  4:00Pm  Portsmouth        Virginia       Urban    White       0        1
# 179  9:00Pm      Cawood        Kentucky       Rural    White       0        2
#
#      Victims   Longitude   Latitude
# 0          1    -75.5849    39.6681
# 1          5    -87.6175    41.8399
# 2          1    -90.1651    38.5657
# 3          1    -78.3118    35.8315
# 4          1  -83.113977  42.383593
# ..       ...         ...        ...
# 175        1 -149.881113  61.213281
# 176        1  -77.378427  37.471892
# 177        1  -80.691593  35.120282
# 178        1  -76.382449  36.826811
# 179        2  -83.229837  36.784261
#
# [180 rows x 14 columns]

# %% [markdown]
# ### Cleaning Kaggle 2 df

# %%
#kaggle_2_df

# %%
# Organizing available columns in desired order
clean_2_df = pd.DataFrame(kaggle_2_df[["school","year","date","time","city","state","killed","injured","long","lat","weapon",
                                       "weapon_source","age_shooter1","gender_shooter1","race_ethnicity_shooter1","shooter_relationship1"]])

# Convert "Date" column to datetime
clean_2_df["date"] = pd.to_datetime(clean_2_df["date"])

# Format the 'Date' column for display
clean_2_df["date"] = clean_2_df["date"].dt.strftime("%m/%d/%Y")

# Renaming the columns
clean_2_df.rename(columns={"long": "Longitude","lat": "Latitude","weapon_source":"Weapon Source", "age_shooter1":"Age",
                           "race_ethnicity_shooter1":"Race",}, inplace=True)

# Proper case the columns
clean_2_df.columns = [col.title() if col.islower() else col for col in clean_2_df]

# Proper case the rows
clean_2_df = clean_2_df.map(lambda x: x.title() if isinstance(x, str) else x)


# Extract school type from the 'School' column and put it in the 'Type' column
clean_2_df.loc[clean_2_df["School"].str.contains("High School", case=False, na=False), "Type"] = "High School"
clean_2_df.loc[clean_2_df["School"].str.contains("Middle School", case=False, na=False), "Type"] = "Middle School"
clean_2_df.loc[clean_2_df["School"].str.contains("Elementary School", case=False, na=False), "Type"] = "Elementary School"
clean_2_df.loc[clean_2_df["School"].str.contains("Junior High", case=False, na=False), "Type"] = "Middle School"


# Rearranging new columns and the first dataframe into desired order
clean_2_df = pd.DataFrame(clean_2_df[["School","Type","Year","Date","Time","City","State","Race","Killed","Injured",
                                     "Longitude","Latitude",
                                      "Weapon","Weapon Source","Age","Gender_Shooter1","Shooter_Relationship1"]])

# Replace NaN with "Unknown"
clean_2_df = clean_2_df.fillna("Unknown")

# Adding the newly labeled data into a new csv for cleanliness
#clean_2_path = Path("clean 2.csv")
#clean_2_df.to_csv(clean_2_path, index=False)

clean_2_df
# Out:
#                                      School               Type  Year  \
# 0                     Columbine High School        High School  1999
# 1               Scotlandville Middle School      Middle School  1999
# 2                      Heritage High School        High School  1999
# 3                  John Bartram High School        High School  1999
# 4                    Dorchester High School        High School  1999
# ..                                      ...                ...   ...
# 382  E. Washington Rhodes Elementary School  Elementary School  2023
# 383                   Roosevelt High School        High School  2023
# 384                         St. John'S Prep                nan  2023
# 385                 Oliver Citywide Academy                nan  2023
# 386         Michigan Collegiate High School        High School  2023
#
#            Date      Time          City                 State     Race  \
# 0    04/20/1999  11:19 Am     Littleton              Colorado        W
# 1    04/22/1999  12:30 Pm   Baton Rouge             Louisiana  Unknown
# 2    05/20/1999   8:03 Am       Conyers               Georgia        W
# 3    10/04/1999  10:00 Am  Philadelphia          Pennsylvania  Unknown
# 4    11/03/1999   7:40 Am        Boston         Massachusetts  Unknown
# ..          ...       ...           ...                   ...      ...
# 382  05/08/2023  11:30 Am  Philadelphia          Pennsylvania  Unknown
# 383  05/17/2023   2:25 Pm    Washington  District Of Columbia  Unknown
# 384  05/22/2023   Unknown       Danvers         Massachusetts  Unknown
# 385  05/24/2023   7:30 Am    Pittsburgh          Pennsylvania  Unknown
# 386  06/05/2023   2:40 Pm        Warren              Michigan        B
#
#      Killed  Injured  Longitude   Latitude  \
# 0        13       21   -105.075   39.60391
# 1         0        1 -91.169966  30.529958
# 2         0        6  -84.04796  33.626922
# 3         0        1 -75.234108  39.921509
# 4         0        1 -71.075901  42.285268
# ..      ...      ...        ...        ...
# 382       0        0   -75.1781    40.0028
# 383       1        0 -77.029177  38.942971
# 384       0        0 -70.952603  42.582682
# 385       1        0 -80.024121  40.464327
# 386       0        0 -83.066681  42.522585
#
#                                                 Weapon  \
# 0    12-Gauge Savage-Springfield 67H Pump-Action Sh...
# 1                                   .22 Caliber Pistol
# 2        .22 Caliber Rifle, 357-Caliber Magnum Handgun
# 3                                Rg .25-Caliber Pistol
# 4                                              Unknown
# ..                                                 ...
# 382                                            Unknown
# 383                                            Unknown
# 384                                            Unknown
# 385                                            Unknown
# 386                                            Handgun
#
#               Weapon Source      Age Gender_Shooter1  \
# 0    Purchased From Friends     18.0               M
# 1                   Unknown     14.0               M
# 2                   Unknown     15.0               M
# 3     Purchased From Friend     17.0               M
# 4                   Unknown  Unknown               M
# ..                      ...      ...             ...
# 382                 Unknown  Unknown         Unknown
# 383                 Unknown  Unknown         Unknown
# 384                 Unknown  Unknown               M
# 385                 Unknown     15.0               M
# 386                 Unknown     22.0               M
#
#          Shooter_Relationship1
# 0                      Student
# 1    Former Student (Expelled)
# 2                      Student
# 3                      Student
# 4                      Unknown
# ..                         ...
# 382                    Student
# 383                    Unknown
# 384             Police Officer
# 385                    Student
# 386       Associate Of Student
#
# [387 rows x 17 columns]

# %% [markdown]
# ### Cleaning shd_df

# %%
#shd_df

# %%
# Organizing available columns in desired order
clean_3_df = pd.DataFrame(shd_df[["school","School_Level","Date","City","State","First_Shot","Bullied","Domestic_Violence","Gang_Related","Preplanned","Quarter","Location"]])

# Convert "Date" column to datetime
clean_3_df["Date"] = pd.to_datetime(clean_3_df["Date"])

# Create the "Year" column by extracting the year from the "Date" column
clean_3_df['Year'] = clean_3_df['Date'].dt.year

# Format the 'Date' column for display
clean_3_df["Date"] = clean_3_df["Date"].dt.strftime('%m/%d/%Y')

# Renaming the columns
clean_3_df.rename(columns={"School_Level": "Type","First_Shot": "Time"}, inplace=True)

# Proper case the columns
clean_3_df.columns = [col.title() if col.islower() else col for col in clean_3_df]

#"weapon", "weapon_source","age_shooter1","gender_shooter1","race_ethnicity_shooter1","shooter_relationship1"

# Extract school type from the 'School' column and put it in the 'Type' column
clean_3_df.loc[clean_3_df["School"].str.contains("High School", case=False, na=False), "Type"] = "High School"
clean_3_df.loc[clean_3_df["School"].str.contains("Middle School", case=False, na=False), "Type"] = "Middle School"
clean_3_df.loc[clean_3_df["School"].str.contains("Elementary School", case=False, na=False), "Type"] = "Elementary School"
clean_3_df.loc[clean_3_df["School"].str.contains("Junior High", case=False, na=False), "Type"] = "Middle School"

# Map state abbreviations to full state names using us package
def get_full_state_name(abbrev):
    try:
        return us.states.lookup(abbrev).name
    except AttributeError:
        return abbrev

clean_3_df["State"] = clean_3_df["State"].apply(get_full_state_name)

# Rearranging new columns and the first dataframe into desired order
clean_3_df = pd.DataFrame(clean_3_df[["School","Type","Date","City","State","Time","Bullied","Domestic_Violence","Gang_Related","Preplanned","Quarter","Location"]])

# Replace NaN with "Unknown"
clean_3_df = clean_3_df.fillna("Unknown")

# Adding the newly labeled data into a new csv for cleanliness
#clean_3_path = Path("clean 3.csv")
#clean_3_df.to_csv(clean_3_path, index=False)

clean_3_df
# Out:
#                                School               Type        Date  \
# 0             Hine Junior High School      Middle School  01/05/1970
# 1                   Sousa Junior High      Middle School  01/05/1970
# 2                 Unnamed High School        High School  01/05/1970
# 3         John F. Kennedy High School        High School  02/06/1970
# 4      David Starr Jordan High School        High School  03/23/1970
# ...                               ...                ...         ...
# 2064  Little Rock School District Bus              Other  06/08/2022
# 2065    Walnut Park Elementary School  Elementary School  06/09/2022
# 2066              Byhalia High School        High School  06/10/2022
# 2067              Mariner High School        High School  06/13/2022
# 2068     Gresham School of Excellence         Elementary  06/20/2022
#
#              City        State      Time  Bullied Domestic_Violence  \
# 0      Washington           DC   Unknown       No                No
# 1      Washington           DC   Unknown       No                No
# 2      Washington           DC   Unknown       No                No
# 3       Cleveland         Ohio   Unknown       No                No
# 4      Long Beach   California   Unknown       No                No
# ...           ...          ...       ...      ...               ...
# 2064  Little Rock     Arkansas  16:01:00       No                No
# 2065      Gadsden      Alabama  09:30:00  Unknown           Unknown
# 2066      Byhalia  Mississippi  10:30:00       No                No
# 2067      Everett   Washington  15:10:00       No                No
# 2068      Chicago     Illinois  01:00:00       No                No
#
#      Gang_Related Preplanned Quarter                Location
# 0              No         No  Winter  Inside School Building
# 1              No         No  Winter                 Hallway
# 2              No         No  Winter              Playground
# 3              No         No  Winter                 Hallway
# 4              No         No  Spring         Beside Building
# ...           ...        ...     ...                     ...
# 2064      Unknown         No  Summer              School Bus
# 2065      Unknown    Unknown  Summer         Front of School
# 2066      Unknown         No  Summer             Parking Lot
# 2067      Unknown         No  Summer             Parking Lot
# 2068      Unknown         No  Summer         Field (General)
#
# [2069 rows x 12 columns]

# %% [markdown]
# ### Merging Data Frames

# %% [markdown]
# drop: "Type_x","Year_x","Date_x","Time_x","City_x","State_x"

# %%
# Merging First dfs
merged_df = pd.merge(clean_1_df, clean_2_df, on=["School","Race", "Killed", "Injured", "Longitude", "Latitude"], how="right") 
clean_merge_df = merged_df.drop(["Type_x","Year_x","Date_x","Time_x","City_x","State_x"],axis = 1)

# Renaming City for final merge
clean_merge_df.rename(columns={"City_y": "City","Type_y": "Type","Year_y":"Year","Date_y":"Date","Time_y":"Time","State_y":"State"}, inplace=True)

clean_merge_df.columns
# Out:
# Index(['School', 'City Type', 'Race', 'Killed', 'Injured', 'Victims',
#        'Longitude', 'Latitude', 'Type', 'Year', 'Date', 'Time', 'City',
#        'State', 'Weapon', 'Weapon Source', 'Age', 'Gender_Shooter1',
#        'Shooter_Relationship1'],
#       dtype='object')

# %% [markdown]
# drop: "City Type", "Victims","Type_x","Date_x","State_y","Time_x"

# %%
# Final Merge
final_df = pd.merge(clean_merge_df, clean_3_df, on=["School","City"])
clean_final_merge = final_df.drop(["City Type", "Victims","Type_x","Date_x","State_y","Time_x"],axis = 1)

# Renaming City for final merge
clean_final_merge.rename(columns={"Type_y": "Type","Date_y": "Date","Time_y":"Time","State_x":"State"}, inplace=True)

# Adding the newly labeled data into a new csv for cleanliness
final_path = Path("Final_Data.csv")
clean_final_merge.to_csv(final_path, index=False)

# %%
# Display Final Dataframe
clean_final_merge
# Out:
#                           School     Race  Killed  Injured   Longitude  \
# 0          Columbine High School        W      13       21    -105.075
# 1    Scotlandville Middle School  Unknown       0        1  -91.169966
# 2           Heritage High School        W       0        6   -84.04796
# 3           Deming Middle School        H       1        0 -107.762986
# 4      Fort Gibson Middle School       Ai       0        5  -95.241921
# ..                           ...      ...     ...      ...         ...
# 312     William Penn High School  Unknown       0        0  -75.584879
# 313     Taylorsville High School  Unknown       0        0 -111.936978
# 314        Palo Duro High School  Unknown       0        1 -101.824434
# 315         Anniston High School  Unknown       0        1      -85.82
# 316     George Wythe High School  Unknown       0        2  -77.483075
#
#       Latitude  Year          City       State  \
# 0     39.60391  1999     Littleton    Colorado
# 1    30.529958  1999   Baton Rouge   Louisiana
# 2    33.626922  1999       Conyers     Georgia
# 3    32.261547  1999        Deming  New Mexico
# 4    35.795556  1999   Fort Gibson    Oklahoma
# ..         ...   ...           ...         ...
# 312  39.668622  2023    New Castle    Delaware
# 313  40.655508  2023  Taylorsville        Utah
# 314  35.228498  2023      Amarillo       Texas
# 315    33.6612  2023      Anniston     Alabama
# 316  37.510274  2023      Richmond    Virginia
#
#                                                 Weapon  ...  \
# 0    12-Gauge Savage-Springfield 67H Pump-Action Sh...  ...
# 1                                   .22 Caliber Pistol  ...
# 2        .22 Caliber Rifle, 357-Caliber Magnum Handgun  ...
# 3                            .22-Caliber Colt Revolver  ...
# 4                                    Taurus 9Mm Pistol  ...
# ..                                                 ...  ...
# 312                                            Handgun  ...
# 313                                            Unknown  ...
# 314                                            Unknown  ...
# 315                                            Unknown  ...
# 316                                            Unknown  ...
#
#          Shooter_Relationship1           Type        Date      Time Bullied  \
# 0                      Student    High School  04/20/1999  11:19 AM     Yes
# 1    Former Student (Expelled)  Middle School  04/22/1999  12:30 PM      No
# 2                      Student    High School  05/20/1999   8:03 AM      No
# 3                      Student  Middle School  11/19/1999  12:45 PM      No
# 4                      Student  Middle School  12/06/1999   7:45 AM      No
# ..                         ...            ...         ...       ...     ...
# 312                    Student    High School  01/08/2009   8:30 PM      No
# 313                    Student    High School  10/12/2001   Unknown      No
# 314                    Unknown    High School  09/11/1992  10:00 AM      No
# 315                    Student    High School  04/30/1982   7:25 AM      No
# 316                    Student    High School  05/19/2022  14:13:00      No
#
#     Domestic_Violence Gang_Related Preplanned Quarter  \
# 0                  No           No        Yes  Spring
# 1                  No           No         No  Spring
# 2                  No           No        Yes  Spring
# 3                  No           No         No    Fall
# 4                  No           No         No  Winter
# ..                ...          ...        ...     ...
# 312                No           No         No  Winter
# 313                No           No         No    Fall
# 314                No           No         No    Fall
# 315                No           No         No  Spring
# 316                No      Unknown         No  Spring
#
#                        Location
# 0                     Cafeteria
# 1               Beside Building
# 2                       Hallway
# 3    Outside on School Property
# 4               Front of School
# ..                          ...
# 312                         Gym
# 313                     Hallway
# 314                     Hallway
# 315                 Parking Lot
# 316                 Parking Lot
#
# [317 rows x 23 columns]

# %%
#Drop duplicates
clean_final_merge = clean_final_merge.drop_duplicates(['Longitude', 'Latitude'])

clean_final_merge
# Out:
#                           School     Race  Killed  Injured   Longitude  \
# 0          Columbine High School        W      13       21    -105.075
# 1    Scotlandville Middle School  Unknown       0        1  -91.169966
# 2           Heritage High School        W       0        6   -84.04796
# 3           Deming Middle School        H       1        0 -107.762986
# 4      Fort Gibson Middle School       Ai       0        5  -95.241921
# ..                           ...      ...     ...      ...         ...
# 311     William Penn High School  Unknown       0        0  -75.584879
# 313     Taylorsville High School  Unknown       0        0 -111.936978
# 314        Palo Duro High School  Unknown       0        1 -101.824434
# 315         Anniston High School  Unknown       0        1      -85.82
# 316     George Wythe High School  Unknown       0        2  -77.483075
#
#       Latitude  Year          City       State  \
# 0     39.60391  1999     Littleton    Colorado
# 1    30.529958  1999   Baton Rouge   Louisiana
# 2    33.626922  1999       Conyers     Georgia
# 3    32.261547  1999        Deming  New Mexico
# 4    35.795556  1999   Fort Gibson    Oklahoma
# ..         ...   ...           ...         ...
# 311  39.668622  2023    New Castle    Delaware
# 313  40.655508  2023  Taylorsville        Utah
# 314  35.228498  2023      Amarillo       Texas
# 315    33.6612  2023      Anniston     Alabama
# 316  37.510274  2023      Richmond    Virginia
#
#                                                 Weapon  ...  \
# 0    12-Gauge Savage-Springfield 67H Pump-Action Sh...  ...
# 1                                   .22 Caliber Pistol  ...
# 2        .22 Caliber Rifle, 357-Caliber Magnum Handgun  ...
# 3                            .22-Caliber Colt Revolver  ...
# 4                                    Taurus 9Mm Pistol  ...
# ..                                                 ...  ...
# 311                                            Handgun  ...
# 313                                            Unknown  ...
# 314                                            Unknown  ...
# 315                                            Unknown  ...
# 316                                            Unknown  ...
#
#          Shooter_Relationship1           Type        Date      Time Bullied  \
# 0                      Student    High School  04/20/1999  11:19 AM     Yes
# 1    Former Student (Expelled)  Middle School  04/22/1999  12:30 PM      No
# 2                      Student    High School  05/20/1999   8:03 AM      No
# 3                      Student  Middle School  11/19/1999  12:45 PM      No
# 4                      Student  Middle School  12/06/1999   7:45 AM      No
# ..                         ...            ...         ...       ...     ...
# 311                    Student    High School  02/09/2006   8:50 PM      No
# 313                    Student    High School  10/12/2001   Unknown      No
# 314                    Unknown    High School  09/11/1992  10:00 AM      No
# 315                    Student    High School  04/30/1982   7:25 AM      No
# 316                    Student    High School  05/19/2022  14:13:00      No
#
#     Domestic_Violence Gang_Related Preplanned Quarter  \
# 0                  No           No        Yes  Spring
# 1                  No           No         No  Spring
# 2                  No           No        Yes  Spring
# 3                  No           No         No    Fall
# 4                  No           No         No  Winter
# ..                ...          ...        ...     ...
# 311                No           No         No  Winter
# 313                No           No         No    Fall
# 314                No           No         No    Fall
# 315                No           No         No  Spring
# 316                No      Unknown         No  Spring
#
#                        Location
# 0                     Cafeteria
# 1               Beside Building
# 2                       Hallway
# 3    Outside on School Property
# 4               Front of School
# ..                          ...
# 311                 Parking Lot
# 313                     Hallway
# 314                     Hallway
# 315                 Parking Lot
# 316                 Parking Lot
#
# [257 rows x 23 columns]

# %% [markdown]
# # Analyzing the Data

# %%
# Annual analysis of # of incidents by year
year_school_df = clean_final_merge.groupby("Year")

#Count of incidents per year
count_year_incident = year_school_df['Year'].count()

count_year_incident
# Out:
# Year
# 1999     5
# 2000     9
# 2001    11
# 2002     4
# 2003     8
# 2004     6
# 2005    10
# 2006    13
# 2007     7
# 2008     5
# 2009     9
# 2010     9
# 2011     5
# 2012     8
# 2013    11
# 2014    13
# 2015     4
# 2016     8
# 2017    13
# 2018    24
# 2019    18
# 2020     6
# 2021    25
# 2022    19
# 2023     7
# Name: Year, dtype: int64

# %%
# Create a bar chart
annual_chart = count_year_incident.plot(kind="bar", figsize=(20,8))

# Rotate x-axis labels
plt.xticks(rotation=45)
plt.xlabel("Incidents")
plt.ylabel("# of Incidents")
plt.title("Incidents per Year")

plt.show()

# %% [markdown]
# # Incident Analysis: Analyzing data by school type, time of day, location

# %% [markdown]
# __Incidents by school types analysis__

# %%
# school type analysis of # of incidents 
school_type_df = clean_final_merge.groupby("Type")

#Count of incidents per year
count_type_incident = school_type_df['Type'].count()

count_type_incident
# Out:
# Type
# 6-12                   3
# Elementary             3
# Elementary School     29
# High                   7
# High School          169
# K-12                   4
# K-8                    3
# Middle                 2
# Middle School         33
# Other                  4
# Name: Type, dtype: int64

# %%
#create sets of school types data
Types_data = {
    'Type': ['6-12', 'Elementary', 'Elementary School', 'High', 'High School', 
             'K-12', 'K-8', 'Middle', 'Middle School', 'Other'],
    'Count': [3, 3, 29, 7, 169, 4, 3, 2, 33, 4]
}

Types_df = pd.DataFrame(Types_data)
Types_df
# Out:
#                 Type  Count
# 0               6-12      3
# 1         Elementary      3
# 2  Elementary School     29
# 3               High      7
# 4        High School    169
# 5               K-12      4
# 6                K-8      3
# 7             Middle      2
# 8      Middle School     33
# 9              Other      4

# %%
#Map types to categories
category_mapping = {
    'Elementary': 'Elementary School',
    'Elementary School': 'Elementary School',
    'Middle': 'Middle School',
    'Middle School': 'Middle School',
    'High': 'High School',
    'High School': 'High School',
    'K-12': 'K-12',
    '6-12': '6-12',
    'K-8': 'K-8',
    'Other': 'Other'
}

#Map the types to categories
Types_df['Category'] = Types_df['Type'].map(category_mapping)

#Groupby categories & display counts
Types_results = Types_df.groupby('Category')['Count'].sum().reset_index()

Types_results
# Out:
#             Category  Count
# 0               6-12      3
# 1  Elementary School     32
# 2        High School    176
# 3               K-12      4
# 4                K-8      3
# 5      Middle School     35
# 6              Other      4

# %%
#set 'category' as index for plotting
Types_results.set_index('Category', inplace=True)

# Create a bar chart
ax = Types_results.plot(kind="bar", figsize=(20,8))

#annotate bars with values
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12, padding=3)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.xlabel("Types of schools")
plt.ylabel("# of Incidents")
plt.title("Incidents per school type (1999-2023)")

plt.show()

# %% [markdown]
# __Time of Incident Analysis__

# %%
# school type analysis of # of incidents 
school_time_df = clean_final_merge.groupby("Time")

#Count of incidents per year
count_time_incident = school_time_df['Time'].count()

clean_final_merge['Time'].unique()
# Out:
# array(['11:19 AM', '12:30 PM', '8:03 AM', '12:45 PM', '7:45 AM',
#        '3:00 PM', '8:34 AM', '12:00 PM', '1:30 PM', '10:30 AM', 'Unknown',
#        '11:50 AM', '12:50 PM', '8:45 AM', '9:20 AM', '12:54 PM',
#        '8:15 AM', '7:20 AM', '7:25 AM', '10:00 AM', '2:40 PM', '2:50 PM',
#        '8:09 AM', '8:30 AM', '12:40 PM', '8:40 AM', '12:15 PM', '7:34 AM',
#        '2:30 PM', '11:38 AM', '8:00 AM', '9:00 AM', '11:45 AM',
#        '12:22 PM', '12:09 PM', '4:00 PM', '1:00 PM', '2:32 PM', '2:00 PM',
#        '9:15 AM', '2:20 PM', '1:25 PM', '9:30 AM', '11:00 AM', '9:45 AM',
#        '1:20 PM', '11:40:00', '8:10 AM', '7:30 AM', '10:45 AM', '8:25 AM',
#        '10:57 AM', '2:15 PM', '10:02 AM', '11:54 AM', '08:11:00',
#        '9:00 PM', '8:20 AM', '8:05 AM', '1:53 PM', '1:45 PM', '15:14:00',
#        '7:51 AM', '9:16 AM', '7:53 AM', '7:30 PM', '10:37 AM', '9:45 PM',
#        '13:30:00', '2:04 PM', '9:35 AM', '1:50 PM', '2:25 PM', '12:04 PM',
#        '7:15 AM', '11:14 AM', '00:00:00', '2:21 PM', '07:30:00',
#        '2:48 PM', '3:30 PM', '12:00 AM', '8:07 AM', '7:40 AM', '10:39 AM',
#        '7:24 AM', '10:00:00', '11:15 AM', '7:50 AM', '11:30 AM',
#        '1:51 PM', '8:33 AM', '11:30:00', '4:30 PM', '08:04:00', '2:08 PM',
#        '7:57 AM', '11:20 AM', '8:55 AM', '4:23 PM', '7:55 AM', '1:44 PM',
#        '08:39:00', '14:30:00', '7:05 AM', '07:15:00', '10:27 AM',
#        '7:00 AM', '10:40 PM', '21:00:00', '08:56:00', '10:07:00',
#        '9:12 AM', '6:00 AM', '12:20 PM', '14:15:00', '07:45:00',
#        '09:59:00', '20:50:00', '22:25:00', '08:05:00', '09:15:00',
#        '15:00:00', '12:45:00', '16:00:00', '11:24:00', '08:00:00',
#        '09:20:00', '15:15:00', '13:50:00', '9:40 PM', '6:00 PM',
#        '14:16:00', '23:57:00', '12:53:00', '12:04:00', '10:30:00',
#        '02:50:00', '11:11:00', '6:30 AM', '00:05:00', '14:45:00',
#        '15:20:00', '13:15:00', '11:20:00', '21:53:00', '8:50 PM',
#        '14:13:00'], dtype=object)

# %%
#Reformat the times to all be the same format
# Iterate over each row and update the 'Time' column
for index, value in clean_final_merge['Time'].items():
    if value != 'Unknown':
        clean_final_merge.loc[index, 'Time'] = pd.Timestamp(value).strftime('%I:%M %p')

# %%
# Convert 'Time' column to datetime format, handling 'Unknown' values
clean_final_merge['Time'] = pd.to_datetime(clean_final_merge['Time'], errors='coerce')

# Define the labels for the time bins
labels = ['Morning', 'Afternoon', 'Evening']

# Function to categorize time into bins
def categorize_time(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour <= 23:
        return 'Evening'
    else:
        return 'Unknown'

# Extract hour from 'Time' column
clean_final_merge['Hour'] = clean_final_merge['Time'].dt.hour

# Apply categorization function to create 'Time_Bin' column
clean_final_merge['Time_Bin'] = clean_final_merge['Hour'].apply(categorize_time)

# Drop 'Hour' column if not needed
clean_final_merge.drop(columns=['Hour'], inplace=True)

# Fill NaN values in 'Time_Bin' column with 'Unknown'
clean_final_merge['Time_Bin'] = clean_final_merge['Time_Bin'].fillna('Unknown')

clean_final_merge
# Out:
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean_final_merge['Time'] = pd.to_datetime(clean_final_merge['Time'], errors='coerce')
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Time'] = pd.to_datetime(clean_final_merge['Time'], errors='coerce')
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Hour'] = clean_final_merge['Time'].dt.hour
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Time_Bin'] = clean_final_merge['Hour'].apply(categorize_time)
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge.drop(columns=['Hour'], inplace=True)
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/814358060.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Time_Bin'] = clean_final_merge['Time_Bin'].fillna('Unknown')
#                           School     Race  Killed  Injured   Longitude  \
# 0          Columbine High School        W      13       21    -105.075
# 1    Scotlandville Middle School  Unknown       0        1  -91.169966
# 2           Heritage High School        W       0        6   -84.04796
# 3           Deming Middle School        H       1        0 -107.762986
# 4      Fort Gibson Middle School       Ai       0        5  -95.241921
# ..                           ...      ...     ...      ...         ...
# 311     William Penn High School  Unknown       0        0  -75.584879
# 313     Taylorsville High School  Unknown       0        0 -111.936978
# 314        Palo Duro High School  Unknown       0        1 -101.824434
# 315         Anniston High School  Unknown       0        1      -85.82
# 316     George Wythe High School  Unknown       0        2  -77.483075
#
#       Latitude  Year          City       State  \
# 0     39.60391  1999     Littleton    Colorado
# 1    30.529958  1999   Baton Rouge   Louisiana
# 2    33.626922  1999       Conyers     Georgia
# 3    32.261547  1999        Deming  New Mexico
# 4    35.795556  1999   Fort Gibson    Oklahoma
# ..         ...   ...           ...         ...
# 311  39.668622  2023    New Castle    Delaware
# 313  40.655508  2023  Taylorsville        Utah
# 314  35.228498  2023      Amarillo       Texas
# 315    33.6612  2023      Anniston     Alabama
# 316  37.510274  2023      Richmond    Virginia
#
#                                                 Weapon  ...           Type  \
# 0    12-Gauge Savage-Springfield 67H Pump-Action Sh...  ...    High School
# 1                                   .22 Caliber Pistol  ...  Middle School
# 2        .22 Caliber Rifle, 357-Caliber Magnum Handgun  ...    High School
# 3                            .22-Caliber Colt Revolver  ...  Middle School
# 4                                    Taurus 9Mm Pistol  ...  Middle School
# ..                                                 ...  ...            ...
# 311                                            Handgun  ...    High School
# 313                                            Unknown  ...    High School
# 314                                            Unknown  ...    High School
# 315                                            Unknown  ...    High School
# 316                                            Unknown  ...    High School
#
#            Date                Time Bullied Domestic_Violence Gang_Related  \
# 0    04/20/1999 2024-05-16 11:19:00     Yes                No           No
# 1    04/22/1999 2024-05-16 12:30:00      No                No           No
# 2    05/20/1999 2024-05-16 08:03:00      No                No           No
# 3    11/19/1999 2024-05-16 12:45:00      No                No           No
# 4    12/06/1999 2024-05-16 07:45:00      No                No           No
# ..          ...                 ...     ...               ...          ...
# 311  02/09/2006 2024-05-16 20:50:00      No                No           No
# 313  10/12/2001                 NaT      No                No           No
# 314  09/11/1992 2024-05-16 10:00:00      No                No           No
# 315  04/30/1982 2024-05-16 07:25:00      No                No           No
# 316  05/19/2022 2024-05-16 14:13:00      No                No      Unknown
#
#     Preplanned Quarter                    Location   Time_Bin
# 0          Yes  Spring                   Cafeteria    Morning
# 1           No  Spring             Beside Building  Afternoon
# 2          Yes  Spring                     Hallway    Morning
# 3           No    Fall  Outside on School Property  Afternoon
# 4           No  Winter             Front of School    Morning
# ..         ...     ...                         ...        ...
# 311         No  Winter                 Parking Lot    Evening
# 313         No    Fall                     Hallway    Unknown
# 314         No    Fall                     Hallway    Morning
# 315         No  Spring                 Parking Lot    Morning
# 316         No  Spring                 Parking Lot  Afternoon
#
# [257 rows x 24 columns]

# %%
# school type analysis of # of incidents 
school_time_df = clean_final_merge.groupby("Time_Bin")

#Count of incidents per year
count_time_incident = school_time_df['Time_Bin'].count()

count_time_incident
# Out:
# Time_Bin
# Afternoon    103
# Evening       14
# Morning      124
# Unknown       16
# Name: Time_Bin, dtype: int64

# %%
#create colors for graph 
colors = ['#FF5733', '#33FF57', '#3357FF', '#FF33A1']

# Create a bar chart
ax = count_time_incident.plot(kind="bar", figsize=(20,8), color=colors[:len(count_time_incident)])

#annotate bars with values
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12, padding=3)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.xlabel("Time of incident")
plt.ylabel("# of Incidents")
plt.title("Incidents per time (1999-2023)")

plt.show()

# %% [markdown]
# **Types of weapons used**

# %%
clean_final_merge['Weapon'].unique()
# Out:
# array(['12-Gauge Savage-Springfield 67H Pump-Action Shotgun, Hi-Point 995 Carbine 9 Mm Carbine, 9_19Mm Intratec Tec-9 Semi-Automatic Handgun, 12-Gauge Stevens 311D Double-Barreled Sawed-Off Shotgun',
#        '.22 Caliber Pistol',
#        '.22 Caliber Rifle, 357-Caliber Magnum Handgun',
#        '.22-Caliber Colt Revolver', 'Taurus 9Mm Pistol',
#        '.22-Caliber Magnum Handgun', '.22 Caliber Revolver', 'Unknown',
#        'Small-Caliber Pistol', '.25-Caliber Handgun',
#        '.22-Caliber Handgun', '.380-Caliber Semiautomatic Handgun',
#        '.38-Caliber Revolver', 'Handgun', '.32-Caliber Handgun',
#        '.22-Caliber Revolver', 'Mossberg Pump-Action 12-Gauge Shotgun',
#        'Pistol', '.380 Caliber Semi-Automatic Pistol',
#        '.357 Magnum Pistol', 'Revolver',
#        '.380-Caliber Semiautomatic Pistol', '.38-Caliber Handgun',
#        '20-Guage Shotgun', '9-Mm Beretta Handgun',
#        'Bushmaster Xm-15 Rifle', 'Browning .380-Caliber Pistol',
#        'Small Semi-Automatic Handgun',
#        '.44-Caliber Handgun, .22-Caliber Gun To Kill Himself',
#        '9Mm Handgun', 'Officer Weapons', '12-Gauge Winchester Shotgun',
#        '.45-Caliber Pistol', '9 Mm Semiautomatic Handgun',
#        'Single-Shot Shotgun', '.380-Caliber Handgun',
#        'High-Powered Rifle', 'Small Revolver',
#        'Small-Caliber Semiautomatic Handgun', 'Ak-47',
#        'Large-Caliber Handgun With Hollow-Point Bullets',
#        '.38-Caliber Pistol',
#        '9 Mm Rifle, A Mossburg 12-Gauge Sawed-Off Shotgun',
#        '.40 S&W Caliber Glock 22 Pistol, Smith & Wesson .357-Caliber Revolver',
#        'Long-Barrel Shotgun, 22-Pistol', 'Mac 90 7.26 Mm Assault Rifle',
#        '9 Mm Semi-Automatic Ruger', '.44 Caliber Handgun',
#        '.270 Winchester Rifle With Scope', '.38 Semiautomatic Handgun',
#        '380-Caliber Handgun', '.22-Caliber Pistol',
#        'Small-Caliber, Semiautomatic Pistol',
#        '.22-Caliber Semi-Automatic Handgun', 'Shotgun',
#        '25-Caliber Nickel Plate Semi-Automatic', '.40-Caliber Handgun',
#        '22-Caliber Rifle', '.40 Caliber Glock', 'Hunting Rifle',
#        '.357-Caliber Magnum Revolver', 'Glock .40-Caliber S&W Pistol',
#        '.357-Caliber Revolver', '.22-Caliber Daisy Rifle',
#        '20-Gauge Shotgun', '.45 Caliber Handgun',
#        'Ruger Mk Iii .22 Caliber Semi-Automatic Handgun',
#        'Charter Arms .44 Bulldog Revolver', '.22-Caliber Ruger Pistol',
#        'Bushmaster Xm15-E2S Rifle', '12-Gauge Shotgun',
#        'Small-Caliber Handgun', '.45-Caliber Semi-Automatic Handgun',
#        '.38 Caliber Handgun', 'Ruger Sr9C Semi-Automatic Handgun (9Mm)',
#        'Ar-15', 'Savage Arms Stevens Model 320 Pump-Action Shotgun',
#        '9Mm Gun (Type Unknown)', 'M4 Ar-15 Rifle',
#        '.40-Caliber Beretta Px4 Storm Handgun', '.357 Magnum',
#        'Semiautomatic Pistol', '.45-Caliber Handgun',
#        '9Mm Beretta Pistol', 'Sig Sauer P238',
#        '9-Mm. Semi-Automatic Handgun', '.40 Caliber Pistol',
#        '.380-Caliber Sig Sauer Pistol',
#        'Smith & Wesson .357 Magnum Revolver',
#        '.380 Caliber Semi-Automatic Handgun', 'Ar-15, Pistol',
#        '.40-Caliber Ruger Semiautomatic Pistol', '9Mm Glock',
#        'Semi-Automatic .380 Caliber Handgun', 'Semi-Automatic Handgun',
#        'Smith & Wesson M&P15', '.38-Caliber Snub-Nosed Revolver',
#        'Glock 21 .45-Caliber Handgun', 'Glock Semi-Automatic Handgun',
#        'Rifle', 'Remington 870 Shotgun And A .38-Caliber Revolver',
#        '.22 Caliber Gun, .45 Caliber Gun', '.45 Caliber Pistol',
#        'Sig Sauer .40 Caliber Handgun', '.380 Pistol',
#        'Handgun And A Rifle', 'Smith And Wesson .40 Caliber Gun',
#        'Taurus .380 Pistol', '2 Handguns', 'Glock', 'Rifle And Shotgun',
#        'Sniper Rifle', 'Ak Pistol'], dtype=object)

# %%
#Create bins for general weapon categories to iterate through weapon names in dataframe
# Define binning rules
binning_rules = {
    'Shotgun': ['Shotgun', 'Pump-Action Shotgun', 'Double-Barreled Sawed-Off Shotgun'],
    'Pistol': ['Pistol', 'Handgun', 'Revolver', 'Glock'],
    'Rifle': ['Rifle', 'Assault Rifle', 'Hunting Rifle'],
    'Unknown': ['Unknown']
}

# Create an empty column for the weapon category
clean_final_merge['Weapon_Category'] = 'Other'

# Loop through each row and apply binning rules
for index, row in clean_final_merge.iterrows():
    weapon = row['Weapon']
    for category, keywords in binning_rules.items():
        for keyword in keywords:
            if keyword.lower() in weapon.lower():
                clean_final_merge.loc[index, 'Weapon_Category'] = category
                break

clean_final_merge[['Weapon_Category', 'Weapon']]
# Out:
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/3440838725.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Weapon_Category'] = 'Other'
#     Weapon_Category                                             Weapon
# 0            Pistol  12-Gauge Savage-Springfield 67H Pump-Action Sh...
# 1            Pistol                                 .22 Caliber Pistol
# 2             Rifle      .22 Caliber Rifle, 357-Caliber Magnum Handgun
# 3            Pistol                          .22-Caliber Colt Revolver
# 4            Pistol                                  Taurus 9Mm Pistol
# ..              ...                                                ...
# 311          Pistol                                            Handgun
# 313         Unknown                                            Unknown
# 314         Unknown                                            Unknown
# 315         Unknown                                            Unknown
# 316         Unknown                                            Unknown
#
# [257 rows x 2 columns]

# %%
#Obtain a value counts of weapon category
# school type analysis of # of incidents 
school_weapon_df = clean_final_merge.groupby("Weapon_Category")

#Count of incidents per year
count_weapon = school_weapon_df['Weapon_Category'].count()

count_weapon
# Out:
# Weapon_Category
# Other       10
# Pistol     149
# Rifle       17
# Shotgun     10
# Unknown     71
# Name: Weapon_Category, dtype: int64

# %%
#make count_shooter_gender a dataframe to display f strings
gun_category_df = pd.DataFrame(count_weapon)

#rename column to incident counts
gun_category_df.columns= ['Incident_count']

gun_category_df
# Out:
#                  Incident_count
# Weapon_Category
# Other                        10
# Pistol                      149
# Rifle                        17
# Shotgun                      10
# Unknown                      71

# %%
#pulling values from dataframe for f strings
other_count = gun_category_df.loc['Other', 'Incident_count']
pistol_count = gun_category_df.loc['Pistol', 'Incident_count']
rifle_count = gun_category_df.loc['Rifle', 'Incident_count']
shotgun_count = gun_category_df.loc['Shotgun', 'Incident_count']
unknowng_count = gun_category_df.loc['Unknown', 'Incident_count']

# %%
#plot pie chart
explode = [0.06 if category == 'Pistol' else 0 for category in count_weapon.index]

plt.figure(figsize= (8,8))
plt.pie(count_weapon, labels=count_weapon.index, autopct='%1.1f%%', startangle=70, 
        explode=explode, shadow=True)
plt.title('Categories of Weapons Used')
plt.axis('equal')

#add f-string annotation 
plt.text(-1.5, 1.5, f"Pistol: {pistol_count} incidents\nRifle: {rifle_count} incidents\nShotgun: {shotgun_count} incidents\nOther: {other_count} incidents\nUnknown: {unknowng_count} incidents", fontsize=12, color='black')

plt.show()

# %% [markdown]
# # Pepetrator Demographics: Traits, Warning Signs/Risk Factors of perpetrator

# %% [markdown]
# **Create a bar graph for age**

# %%
#clean_final_merge['Age']
# Convert 'unknown' strings to NaN
clean_final_merge['Age'] = pd.to_numeric(clean_final_merge['Age'], errors='coerce')
#clean_final_merge['Age']

#conduct a groupby
grouped_age = clean_final_merge.groupby('Age')

counted_age = grouped_age['Age'].count()

counted_age
# Out:
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/2094393704.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Age'] = pd.to_numeric(clean_final_merge['Age'], errors='coerce')
# Age
# 7.0      1
# 8.0      2
# 9.0      1
# 11.0     2
# 12.0     5
# 13.0    10
# 14.0    23
# 15.0    36
# 16.0    26
# 17.0    24
# 18.0    14
# 19.0     8
# 20.0     3
# 21.0     4
# 22.0     2
# 23.0     2
# 24.0     1
# 25.0     1
# 26.0     2
# 27.0     1
# 28.0     3
# 29.0     1
# 30.0     2
# 32.0     1
# 33.0     1
# 34.0     1
# 38.0     2
# 39.0     1
# 41.0     2
# 44.0     1
# 45.0     2
# 47.0     2
# 49.0     1
# 50.0     1
# 53.0     3
# 55.0     1
# 72.0     1
# Name: Age, dtype: int64

# %%
# Create a bar chart
ax = counted_age.plot(kind="bar", figsize=(20,8))

#annotate bars with values
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=12, padding=3)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.xlabel("Age")
plt.ylabel("# of Incidents")
plt.title("Age of shooter per incident(1999-2023)")

plt.show()

#calculate statistics
#drop unknown
#Drop counts for 'Unknown'
# Convert 'unknown' strings to NaN
clean_final_merge['Age'] = pd.to_numeric(clean_final_merge['Age'], errors='coerce')

# Calculate the mean age
mean_age = clean_final_merge['Age'].mean()
median_age = clean_final_merge['Age'].median()
mode_age = clean_final_merge['Age'].mode()


#print mean, median, & mode beneath graph
print(f'Average Age: {mean_age}')
print(f'Median Age: {median_age}')
print(f'Mode Age: {mode_age}')
# Out:
# Average Age: 19.47422680412371
# Median Age: 16.0
# Mode Age: 0    15.0
# Name: Age, dtype: float64
# /var/folders/rz/6tnzmsj50s75hgrnq67ygmm00000gn/T/ipykernel_32205/1910130331.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_final_merge['Age'] = pd.to_numeric(clean_final_merge['Age'], errors='coerce')

# %% [markdown]
# **Create a pie plot for gender of shooter & a line graph for gender of shooter over time**

# %%
#group original df by shooter gender
shooter_gender_df = clean_final_merge.groupby("Gender_Shooter1")

#Count of incidents per year
count_shooter_gender = shooter_gender_df['Gender_Shooter1'].count()

#Drop counts for 'H'
count_shooter_gender = count_shooter_gender.drop('H', errors='ignore')

count_shooter_gender
# Out:
# Gender_Shooter1
# F            9
# M          204
# Unknown     43
# Name: Gender_Shooter1, dtype: int64

# %%
#make count_shooter_gender a dataframe to display f strings
cs_sh = pd.DataFrame(count_shooter_gender)

#rename column to incident counts
cs_sh.columns= ['Incident_count']

cs_sh
# Out:
#                  Incident_count
# Gender_Shooter1
# F                             9
# M                           204
# Unknown                      43

# %%
#pulling values from dataframe for f strings
male_count = cs_sh.loc['M', 'Incident_count']
female_count = cs_sh.loc['F', 'Incident_count']
unknown_count = cs_sh.loc['Unknown', 'Incident_count']

# %%
#create pie plot
explode = [0.08 if category == 'M' else 0 for category in count_shooter_gender.index]

plt.figure(figsize= (8,8))
plt.pie(count_shooter_gender, labels=count_shooter_gender.index, autopct='%1.1f%%', startangle=180, 
        explode=explode, shadow=True)
plt.title('Categories of Weapons Used')
plt.axis('equal')

#add f-string annotation 
plt.text(-1.5, 1.5, f"Male: {male_count} incidents\nFemale: {female_count} incidents\nUnknown: {unknown_count} incidents", fontsize=12, color='black')

plt.show()

# %%
#Filter the DataFrame to exclude rows where shooter_gender is 'H'
filtered_df = clean_final_merge[clean_final_merge['Gender_Shooter1'] != 'H']

# Grouping the filtered data by 'shooter_gender' and 'year' and counting the incidents
gender_year_counts = filtered_df.groupby(['Gender_Shooter1', 'Year']).size().unstack(fill_value=0)

# Plotting the line graph
plt.figure(figsize=(10, 6))  # Adjust size if needed
for gender in gender_year_counts.index:
    plt.plot(gender_year_counts.columns, gender_year_counts.loc[gender], label=gender)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Incidents')
plt.title('Incidents by Gender over the Years')
plt.legend()

# Display the plot
plt.grid(True)  # Add grid lines
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
clean_final_merge[['Bullied', 'Domestic_Violence']]
# Out:
#     Bullied Domestic_Violence
# 0       Yes                No
# 1        No                No
# 2        No                No
# 3        No                No
# 4        No                No
# ..      ...               ...
# 311      No                No
# 313      No                No
# 314      No                No
# 315      No                No
# 316      No                No
#
# [257 rows x 2 columns]

# %%
# Counting the occurrences of 'yes' and 'no' for each column
bullied_counts = clean_final_merge['Bullied'].value_counts()
domestic_violence_counts = clean_final_merge['Domestic_Violence'].value_counts()

# Creating a DataFrame for plotting
counts_df = pd.DataFrame({
    'Bullied': bullied_counts,
    'Domestic_Violence': domestic_violence_counts
})

# Plotting
counts_df.plot(kind='bar', stacked=False)
plt.xticks(rotation=45, ha='right')
plt.title('Counts of Shooter History for Bullying & Domestic Violence')
plt.xlabel('Response')
plt.ylabel('Count')
plt.show()

#save figure
plt.savefig("Bullying_DV.png")
